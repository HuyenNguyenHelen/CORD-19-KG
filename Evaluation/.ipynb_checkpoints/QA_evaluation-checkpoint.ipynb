# %% [markdown]
# # Evaluate KG on the QA task

# %% [markdown]
# ## Process the groundtruth

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading the groundtruth
with open(r"C:\Users\huyen\OneDrive\Documents\GitHub\CORD-19-KG\Evaluation\groundtruth\expert_answers_copy.csv", 'r') as f:
    gtruth = pd.read_csv(f)
gtruth.head()
# Out:
#   QueryID                                             answer
# 0      Q1  Membrane Protein, M Protein, m protein ectodomain
# 1      Q1  Envelope Protein, E Protein, protein e, envelo...
# 2      Q1                    Nucleocapsid Protein, N Protein
# 3      Q1  Spike Protein, S Protein, coronavirus s protei...
# 4      Q2                                 Bat, horseshoe bat

# %%
# Group the groundtruth by groups
gtruth_group = gtruth.groupby(by = ['QueryID']).agg(lambda x: list(x)).reset_index()
# data3 = data.fillna('').groupby(by = ['QueryID', 'Main_text']).agg(lambda x: list(x)).reset_index()
gtruth_group['length'] = gtruth_group['answer'].apply(lambda x: len(x))
gtruth_group
# Out:
#   QueryID                                             answer  length
# 0      Q1  [Membrane Protein, M Protein, m protein ectodo...       4
# 1      Q2  [ Bat, horseshoe bat,  mink,  white-tailed dee...       5
# 2      Q3  [cough, dry cough, coughing, fever, amnesia, h...      23
# 3      Q4  [symptomatic treatment, antiviral drug, antivi...       6
# 4      Q5  [tocilizumab, hydroxychloroquine, Acetaminophe...      16

# %% [markdown]
# ## Process the answer file

# %%
      
class Evaluation:
    
    def __init__(self, ground_truth, retrieved_anws):
        self.ground_truth = ground_truth
        self.retrieved_anws = retrieved_anws  
        retrieved_anws.columns = ['unk', 'answer', 'label']
        self.tp = retrieved_anws['label'].value_counts()[1]
        not_in_anws = []
        for list_ in gtruth_group['answer']:
            for item in list_:
                if len(item.split(',')) <2:
                    anw = item.lower()
                    if anw not in retrieved_anws['answer'].tolist():
                        not_in_anws.append(anw)
                else:
                    condition = any(i.lower() in retrieved_anws['answer'].tolist() for i in item.split(', '))
                    if condition is False:
                        not_in_anws.append(item)
        self.fn = len(not_in_anws)
    
        try:
            self.fp = retrieved_anws['label'].value_counts()[0]
        except:
            self.fp=0
        
    def precision(self):
        precision = self.tp/(self.tp + self.fp)
        return precision
    
    def recall (self):
        recall = self.tp/(self.tp + self.fn)
        return recall
    
    def F1 (self):
        f1_score = (2*self.precision()*self.recall())/(self.precision()+self.recall())

        return f1_score


############ Calculate the scores and write them to file #######

n_folders = 10
n_queries = 5
all_scores = []

# with open(r'C:\Users\huyen\OneDrive\Documents\GitHub\CORD-19-KG\Evaluation\result\scores.txt', 'w') as file:
#             file.write('folder,query,precision,recall,F1\n')
for i in range (1,n_folders+1):
    query_scores = {}
    for j in range(1,n_queries+1):
        query_scores['query_%s'%j]=[]
        file_p = r"C:\Users\huyen\OneDrive\Documents\GitHub\CORD-19-KG\Results\KG-output-neo4j-2\subset_{}\query_{}.csv".format(i, j)
        with open(file_p, 'r') as f:
            anws_q = pd.read_csv(f)
        len_gold_q = gtruth_group[gtruth_group['QueryID']=='Q%s'%j]['length'].values[0]
        evaluation = Evaluation(len_gold_q,anws_q)
        precision_q = evaluation.precision()
        recall_q = evaluation.recall()
        F1_q = evaluation.F1()
        print('Folder {} -- Query {}: precision: {:.3f}, recall: {:.3f}, F1: {:.3f}\n'.format(i, j, precision_q, recall_q, F1_q))
        query_scores['query_%s'%j].append(precision_q)
        query_scores['query_%s'%j].append(recall_q)
        query_scores['query_%s'%j].append(F1_q)
#         with open(r'C:\Users\huyen\OneDrive\Documents\GitHub\CORD-19-KG\Evaluation\result\scores.txt', 'a') as file:
#             file.write('{},{},{:.3f},{:.3f},{:.3f}\n'.format(i, j, precision_q, recall_q, F1_q))

    all_scores.append(query_scores)
# Out:
# Folder 1 -- Query 1: precision: 0.081, recall: 0.055, F1: 0.065
#
# Folder 1 -- Query 2: precision: 0.455, recall: 0.086, F1: 0.145
#
# Folder 1 -- Query 3: precision: 1.000, recall: 0.019, F1: 0.036
#
# Folder 1 -- Query 4: precision: 0.250, recall: 0.037, F1: 0.065
#
# Folder 1 -- Query 5: precision: 0.250, recall: 0.056, F1: 0.091
#
# Folder 2 -- Query 1: precision: 0.109, recall: 0.125, F1: 0.117
#
# Folder 2 -- Query 2: precision: 0.385, recall: 0.086, F1: 0.141
#
# Folder 2 -- Query 3: precision: 0.250, recall: 0.019, F1: 0.034
#
# Folder 2 -- Query 4: precision: 0.250, recall: 0.073, F1: 0.113
#
# Folder 2 -- Query 5: precision: 0.214, recall: 0.056, F1: 0.088
#
# Folder 3 -- Query 1: precision: 0.087, recall: 0.109, F1: 0.097
#
# Folder 3 -- Query 2: precision: 0.318, recall: 0.119, F1: 0.173
#
# Folder 3 -- Query 3: precision: 0.333, recall: 0.056, F1: 0.095
#
# Folder 3 -- Query 4: precision: 0.300, recall: 0.105, F1: 0.156
#
# ...

# %%
with open(r"C:\Users\huyen\OneDrive\Documents\GitHub\CORD-19-KG\Evaluation\result\scores.txt", 'r') as file:
    results = pd.read_csv(file, delimiter = ',')
results.head()
# Out:
#    folder  query  precision  recall     F1
# 0       1      1      0.081   0.055  0.065
# 1       1      2      0.455   0.086  0.145
# 2       1      3      1.000   0.019  0.036
# 3       1      4      0.250   0.037  0.065
# 4       1      5      0.250   0.056  0.091

# %% [markdown]
# # Result vizualization

# %%
############## Reformat the output for viz   ################

by_queries = {}
for j in range(1,6):
    by_queries['query_%s'%j]=[]
    for i,fold_result in enumerate(all_scores):
        by_queries['query_%s'%j].append(fold_result['query_%s'%j])
by_queries

##################### Vizualization ##########################

# Set color for each model
colors = {'query_1': 'lightcoral','query_2': 'darkorange', 'query_3':'lime', 'query_4': 'steelblue',
          'query_5': 'purple'}

# Set marker for each model          
markers = {'query_1':'1--','query_2': 'v--', 'query_3': '^--', 'query_4': '*--', 'query_5': 'o--'}

def viz_performance(metric):
    plt.figure(figsize=(9,6))
    if metric == 'precision':
        key = 0
    elif metric == 'recall':
        key= 1
    elif metric == 'F1':
        key = 2
    else:
        raise ValueError ('Error: wrong evaluation metric given!')
    for query, fold_scores in by_queries.items():
        y = [scores[key] for scores in fold_scores]
        x = [i for i in range(1,11)]
        plt.plot(x,y, markers[query], color=colors[query], label= query )

    plt.ylabel(metric)
    plt.xlabel('subsets')
    plt.legend(loc='upper left', ncol = 2) 
    plt.title( '%s scores over 10 subsets'%metric)
    plt.show()
    plt.savefig(r"C:\Users\huyen\OneDrive\Documents\GitHub\CORD-19-KG\Evaluation\result\%s.png" %metric )
    
viz_performance('F1')
viz_performance('precision')
viz_performance('recall')
